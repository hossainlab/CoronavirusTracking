# %% [markdown]
# # 2019-nCoV Tracking

# %%
from IPython.display import IFrame
IFrame('https://gisanddata.maps.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6', height=700, width=960)
# Out:
#         <iframe
#             width="960"
#             height="700"
#             src="https://gisanddata.maps.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.offline as pyo 
import plotly.graph_objs as go

# %%
# Read data from Johns Hopkins University
df = pd.read_excel('./data/Novel Coronavirus (2019-nCoV) Cases, provided by JHU CSSE.xlsx')

# %%
# Check missing data in dataset
df.isnull().sum()
# Out:
# Province/State    21
# Country/Region     0
# Last Update        0
# Confirmed          0
# Deaths             0
# Recovered          0
# dtype: int64

# %%
# Drop missing data from dataset and create a new df 
cv_df = df.dropna()

# %%
cv_df
# Out:
#       Province/State  Country/Region         Last Update  Confirmed  Deaths  \
# 0              Hubei  Mainland China 2020-02-04 23:43:00      16678     479
# 1           Zhejiang  Mainland China 2020-02-05 01:33:00        895       0
# 2          Guangdong  Mainland China 2020-02-05 02:03:00        870       0
# 3              Henan  Mainland China 2020-02-05 01:13:00        764       2
# 4              Hunan  Mainland China 2020-02-05 01:43:00        661       0
# 5            Jiangxi  Mainland China 2020-02-05 01:33:00        548       0
# 6              Anhui  Mainland China 2020-02-05 01:13:00        530       0
# 7          Chongqing  Mainland China 2020-02-05 00:13:00        366       2
# 8            Jiangsu  Mainland China 2020-02-05 02:43:00        341       0
# 9            Sichuan  Mainland China 2020-02-05 00:53:00        301       1
# 10          Shandong  Mainland China 2020-02-05 01:03:00        298       0
# 11          Shanghai  Mainland China 2020-02-05 00:23:00        233       1
# 12           Beijing  Mainland China 2020-02-04 08:33:00        228       1
# 13            Fujian  Mainland China 2020-02-04 12:13:00        194       0
# 14      Heilongjiang  Mainland China 2020-02-05 01:23:00        190       2
# 15           Shaanxi  Mainland China 2020-02-05 02:43:00        165       0
# 16           Guangxi  Mainland China 2020-02-05 00:43:00        150       0
# 17             Hebei  Mainland China 2020-02-05 02:53:00        135       1
# 18            Yunnan  Mainland China 2020-02-04 23:23:00        122       0
# 19            Hainan  Mainland China 2020-02-05 02:53:00         91       1
# 20          Liaoning  Mainland China 2020-02-04 14:13:00         81       0
# 21            Shanxi  Mainland China 2020-02-04 23:23:00         81       0
# 22           Tianjin  Mainland China 2020-02-04 13:33:00         67       0
# 23           Guizhou  Mainland China 2020-02-05 01:23:00         64       0
# 24             Gansu  Mainland China 2020-02-04 15:43:00         57       0
# 25             Jilin  Mainland China 2020-02-05 00:43:00         54       0
# 26    Inner Mongolia  Mainland China 2020-02-05 01:53:00         42       0
# 27           Ningxia  Mainland China 2020-02-04 02:13:00         34       0
# 28          Xinjiang  Mainland China 2020-02-05 02:03:00         32       0
# 32         Hong Kong       Hong Kong 2020-02-05 02:33:00         18       1
# 33           Qinghai  Mainland China 2020-02-05 01:23:00         17       0
# 36            Taiwan          Taiwan 2020-02-04 14:53:00         11       0
# 37             Macau           Macau 2020-02-04 04:43:00         10       0
# 42   New South Wales       Australia 2020-02-01 18:12:00          4       0
# 43          Victoria       Australia 2020-02-01 18:12:00          4       0
# 44        Queensland       Australia 2020-02-04 16:53:00          3       0
# 46   South Australia       Australia 2020-02-02 22:33:00          2       0
# 47       Toronto, ON          Canada 2020-02-04 00:13:00          2       0
# 52       Chicago, IL              US 2020-02-01 19:43:00          2       0
# 53    San Benito, CA              US 2020-02-03 03:53:00          2       0
# 54   Santa Clara, CA              US 2020-02-03 00:43:00          2       0
# 57  British Columbia          Canada 2020-02-01 18:12:00          1       0
# 58        London, ON          Canada 2020-02-04 00:03:00          1       0
# 60             Tibet  Mainland China 2020-02-01 01:52:00          1       0
# 65        Boston, MA              US 2020-02-01 19:43:00          1       0
# 66   Los Angeles, CA              US 2020-02-01 19:53:00          1       0
# 67        Orange, CA              US 2020-02-01 19:53:00          1       0
# 68       Seattle, WA              US 2020-02-01 19:43:00          1       0
# 69         Tempe, AZ              US 2020-02-01 19:43:00          1       0
#
#     Recovered
# 0         522
# 1          63
# 2          32
# 3          41
# 4          35
# 5          27
# 6          20
# 7          14
# 8          13
# 9          23
# 10         13
# 11         12
# 12         23
# 13          3
# 14          4
# 15          2
# 16         10
# 17          4
# 18          5
# 19          4
# 20          2
# 21          4
# 22          2
# 23          5
# 24          4
# 25          1
# 26          1
# 27          1
# 28          0
# 32          0
# 33          0
# 36          0
# 37          0
# 42          2
# 43          0
# 44          0
# 46          0
# 47          0
# 52          0
# 53          0
# 54          0
# 57          0
# 58          0
# 60          0
# 65          0
# 66          0
# 67          0
# 68          0
# 69          0

# %%
# Check missing value again
cv_df.isnull().sum()
# Out:
# Province/State    0
# Country/Region    0
# Last Update       0
# Confirmed         0
# Deaths            0
# Recovered         0
# dtype: int64

# %% [markdown]
# ## Spread of nCoV around the world

# %%
cv_df
# Out:
#       Province/State  Country/Region         Last Update  Confirmed  Deaths  \
# 0              Hubei  Mainland China 2020-02-04 23:43:00      16678     479
# 1           Zhejiang  Mainland China 2020-02-05 01:33:00        895       0
# 2          Guangdong  Mainland China 2020-02-05 02:03:00        870       0
# 3              Henan  Mainland China 2020-02-05 01:13:00        764       2
# 4              Hunan  Mainland China 2020-02-05 01:43:00        661       0
# 5            Jiangxi  Mainland China 2020-02-05 01:33:00        548       0
# 6              Anhui  Mainland China 2020-02-05 01:13:00        530       0
# 7          Chongqing  Mainland China 2020-02-05 00:13:00        366       2
# 8            Jiangsu  Mainland China 2020-02-05 02:43:00        341       0
# 9            Sichuan  Mainland China 2020-02-05 00:53:00        301       1
# 10          Shandong  Mainland China 2020-02-05 01:03:00        298       0
# 11          Shanghai  Mainland China 2020-02-05 00:23:00        233       1
# 12           Beijing  Mainland China 2020-02-04 08:33:00        228       1
# 13            Fujian  Mainland China 2020-02-04 12:13:00        194       0
# 14      Heilongjiang  Mainland China 2020-02-05 01:23:00        190       2
# 15           Shaanxi  Mainland China 2020-02-05 02:43:00        165       0
# 16           Guangxi  Mainland China 2020-02-05 00:43:00        150       0
# 17             Hebei  Mainland China 2020-02-05 02:53:00        135       1
# 18            Yunnan  Mainland China 2020-02-04 23:23:00        122       0
# 19            Hainan  Mainland China 2020-02-05 02:53:00         91       1
# 20          Liaoning  Mainland China 2020-02-04 14:13:00         81       0
# 21            Shanxi  Mainland China 2020-02-04 23:23:00         81       0
# 22           Tianjin  Mainland China 2020-02-04 13:33:00         67       0
# 23           Guizhou  Mainland China 2020-02-05 01:23:00         64       0
# 24             Gansu  Mainland China 2020-02-04 15:43:00         57       0
# 25             Jilin  Mainland China 2020-02-05 00:43:00         54       0
# 26    Inner Mongolia  Mainland China 2020-02-05 01:53:00         42       0
# 27           Ningxia  Mainland China 2020-02-04 02:13:00         34       0
# 28          Xinjiang  Mainland China 2020-02-05 02:03:00         32       0
# 32         Hong Kong       Hong Kong 2020-02-05 02:33:00         18       1
# 33           Qinghai  Mainland China 2020-02-05 01:23:00         17       0
# 36            Taiwan          Taiwan 2020-02-04 14:53:00         11       0
# 37             Macau           Macau 2020-02-04 04:43:00         10       0
# 42   New South Wales       Australia 2020-02-01 18:12:00          4       0
# 43          Victoria       Australia 2020-02-01 18:12:00          4       0
# 44        Queensland       Australia 2020-02-04 16:53:00          3       0
# 46   South Australia       Australia 2020-02-02 22:33:00          2       0
# 47       Toronto, ON          Canada 2020-02-04 00:13:00          2       0
# 52       Chicago, IL              US 2020-02-01 19:43:00          2       0
# 53    San Benito, CA              US 2020-02-03 03:53:00          2       0
# 54   Santa Clara, CA              US 2020-02-03 00:43:00          2       0
# 57  British Columbia          Canada 2020-02-01 18:12:00          1       0
# 58        London, ON          Canada 2020-02-04 00:03:00          1       0
# 60             Tibet  Mainland China 2020-02-01 01:52:00          1       0
# 65        Boston, MA              US 2020-02-01 19:43:00          1       0
# 66   Los Angeles, CA              US 2020-02-01 19:53:00          1       0
# 67        Orange, CA              US 2020-02-01 19:53:00          1       0
# 68       Seattle, WA              US 2020-02-01 19:43:00          1       0
# 69         Tempe, AZ              US 2020-02-01 19:43:00          1       0
#
#     Recovered
# 0         522
# 1          63
# 2          32
# 3          41
# 4          35
# 5          27
# 6          20
# 7          14
# 8          13
# 9          23
# 10         13
# 11         12
# 12         23
# 13          3
# 14          4
# 15          2
# 16         10
# 17          4
# 18          5
# 19          4
# 20          2
# 21          4
# 22          2
# 23          5
# 24          4
# 25          1
# 26          1
# 27          1
# 28          0
# 32          0
# 33          0
# 36          0
# 37          0
# 42          2
# 43          0
# 44          0
# 46          0
# 47          0
# 52          0
# 53          0
# 54          0
# 57          0
# 58          0
# 60          0
# 65          0
# 66          0
# 67          0
# 68          0
# 69          0

# %% [markdown]
# ### Spread of nCoV around the world: Confirmed Cases

# %%
# Confirmed Cases 
data = [go.Bar(
    x = cv_df['Province/State'], 
    y = cv_df['Confirmed'], 
    marker= dict(color='#CD7F32')

)]

layout = go.Layout(
    title = 'Novel Coronavirus (2019-nCoV) confirmed cases aroud the world', 
    xaxis = dict(title="Province/State"), 
    yaxis = dict(title='Confirmed')
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename='cv_confimed.html')
# Out:
# 'cv_confimed.html'

# %% [markdown]
# ### Spread of nCoV around the world: Recovered Cases

# %%
# Recovered Cases 
data = [go.Bar(
    x = cv_df['Province/State'], 
    y = cv_df['Recovered'], 
    marker= dict(color='#CD7F32')

)]

layout = go.Layout(
    title = 'Novel Coronavirus (2019-nCoV) recovered cases aroud the world', 
    xaxis = dict(title="Province/State"), 
    yaxis = dict(title='Recovered')
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename='cv_recovered.html')
# Out:
# 'cv_recovered.html'

# %% [markdown]
# ### Spread of nCoV around the world: Deaths Cases

# %%
# Deaths Cases
data = [go.Bar(
    x = cv_df['Province/State'], 
    y = cv_df['Deaths'], 
    marker= dict(color='#CD7F32')

)]

layout = go.Layout(
    title = 'Novel Coronavirus (2019-nCoV) death cases aroud the world', 
    xaxis = dict(title="Province/State"), 
    yaxis = dict(title='Deaths')
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename='cv_deaths.html')
# Out:
# 'cv_deaths.html'

# %% [markdown]
# ## Spread of nCoV in China

# %%
china= cv_df[cv_df['Country/Region'] == 'Mainland China']
china_data= pd.DataFrame(china.groupby(['Province/State'])['Last Update','Confirmed','Recovered','Deaths'].agg('sum')).reset_index()
china_data.head(10)
# Out:
#   Province/State  Confirmed  Recovered  Deaths
# 0          Anhui        530         20       0
# 1        Beijing        228         23       1
# 2      Chongqing        366         14       2
# 3         Fujian        194          3       0
# 4          Gansu         57          4       0
# 5      Guangdong        870         32       0
# 6        Guangxi        150         10       0
# 7        Guizhou         64          5       0
# 8         Hainan         91          4       1
# 9          Hebei        135          4       1

# %% [markdown]
# ### Spread of nCoV in China: Confirmed Cases

# %%
data = [go.Bar(
    x = china_data['Province/State'], 
    y = china_data['Confirmed'], 
    marker= dict(color='#CD7F32')

)]

layout = go.Layout(
    title = 'Novel Coronavirus (2019-nCoV) Confirmed Cases in China', 
    xaxis = dict(title="Province/State"), 
    yaxis = dict(title='Confirmed')
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename='confimed.html')
# Out:
# 'confimed.html'

# %% [markdown]
# ### Spread of nCoV in China: Recovered Cases

# %%
data = [go.Bar(
    x = china_data['Province/State'], 
    y = china_data['Recovered'], 
    marker= dict(color='#FFDD11')

)]

layout = go.Layout(
    title = 'Novel Coronavirus (2019-nCoV) Recovered Cases in China', 
    xaxis = dict(title="Province/State"), 
    yaxis = dict(title='Recovered')
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename='Recovered.html')
# Out:
# 'Recovered.html'

# %% [markdown]
# ### Spread of nCoV in China: Deaths Cases

# %%
data = [go.Bar(
    x = china_data['Province/State'], 
    y = china_data['Deaths'], 
    marker= dict(color='#1126FF')

)]

layout = go.Layout(
    title = 'Novel Coronavirus (2019-nCoV) Death Cases in China', 
    xaxis = dict(title="Province/State"), 
    yaxis = dict(title='Deaths')
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename='deaths.html')
# Out:
# 'deaths.html'

# %% [markdown]
# ## Spread of nCoV by DateTime

# %%
data_by_datetime = cv_df.groupby('Last Update').sum().reset_index()

# %%
data_by_datetime
# Out:
#            Last Update  Confirmed  Deaths  Recovered
# 0  2020-02-01 01:52:00          1       0          0
# 1  2020-02-01 18:12:00          9       0          2
# 2  2020-02-01 19:43:00          5       0          0
# 3  2020-02-01 19:53:00          2       0          0
# 4  2020-02-02 22:33:00          2       0          0
# 5  2020-02-03 00:43:00          2       0          0
# 6  2020-02-03 03:53:00          2       0          0
# 7  2020-02-04 00:03:00          1       0          0
# 8  2020-02-04 00:13:00          2       0          0
# 9  2020-02-04 02:13:00         34       0          1
# 10 2020-02-04 04:43:00         10       0          0
# 11 2020-02-04 08:33:00        228       1         23
# 12 2020-02-04 12:13:00        194       0          3
# 13 2020-02-04 13:33:00         67       0          2
# 14 2020-02-04 14:13:00         81       0          2
# 15 2020-02-04 14:53:00         11       0          0
# 16 2020-02-04 15:43:00         57       0          4
# 17 2020-02-04 16:53:00          3       0          0
# 18 2020-02-04 23:23:00        203       0          9
# 19 2020-02-04 23:43:00      16678     479        522
# 20 2020-02-05 00:13:00        366       2         14
# 21 2020-02-05 00:23:00        233       1         12
# 22 2020-02-05 00:43:00        204       0         11
# 23 2020-02-05 00:53:00        301       1         23
# 24 2020-02-05 01:03:00        298       0         13
# 25 2020-02-05 01:13:00       1294       2         61
# 26 2020-02-05 01:23:00        271       2          9
# 27 2020-02-05 01:33:00       1443       0         90
# 28 2020-02-05 01:43:00        661       0         35
# 29 2020-02-05 01:53:00         42       0          1
# 30 2020-02-05 02:03:00        902       0         32
# 31 2020-02-05 02:33:00         18       1          0
# 32 2020-02-05 02:43:00        506       0         15
# 33 2020-02-05 02:53:00        226       2          8
